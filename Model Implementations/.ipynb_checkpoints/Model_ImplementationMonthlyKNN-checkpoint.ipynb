# %%
import pandas as pd
import time
from datetime import datetime
from alpha_vantage.timeseries import TimeSeries
import random
import urllib
import sqlalchemy
import matplotlib.pyplot as plt
import sys
import tensorflow as tf
import keras
import numpy as np

position = {}
remaining_cash = 10000.00
capital = 10000.00
loss = 0
win = 0
total_valuation = 0    
profit = 0
commission = 5
buy_times = 0
min_loss = 0
max_profit = 0

# %%
params = urllib.parse.quote("DRIVER={ODBC Driver 13 for SQL Server};SERVER=localhost;DATABASE=StocksDMW;Trusted_Connection=yes")
engine = sqlalchemy.create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)

# %%
symbols = """
select distinct(name) from stockdatamonthly order by name
"""
symbol_list = pd.read_sql(symbols, engine)

# %%
symbol_list = symbol_list['name'].tolist()

# %% [markdown]
# <h1> Instantation of variables

# %%
class equity():
    bought = None
    support = None
    resistance = None
    resistance_date = None
    stop_order = None
    times_bought = 0
    symbol = None
    dataframe = None
    current_price = None
   
    flag_for_wins = False
    
    def __init__(self, name):
        self.symbol = name
      

sql1= """
select distinct(name) from stockdatamonthly order by name
"""
names = pd.read_sql(sql1,engine)['name'].tolist()

stock_equities = {}
for name in names:
    stock_equities[name] = equity(name)

# %% [markdown]
# <h1> Updating resources

# %%
cursor = len(symbol_list)
percent = cursor // 100


counter = 0
percentage = 0
for symbol in symbol_list:
    if(counter % percent == 0 ):
        print(percentage , "% done")
        percentage += 1
    symbol_data = """
    select * from stockdatamonthly where name = '%s'
    """ % symbol
    counter += 1
    stock_equities[symbol].dataframe = pd.read_sql(symbol_data,engine)
# Out:
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done

# %%
sql_dates = """
select distinct(date) from stockdatamonthly order by date
"""
dates = pd.read_sql(sql_dates, engine)['date'].tolist()

# %% [markdown]
# <h1> Loading KNN Model

# %%
import pickle

pickle_in = open("KNN-ModelMonthly59.pickle","rb")
model = pickle.load(pickle_in)

# %% [markdown]
# <h1> Trading strategy with the training sets generation

# %%
def automatic_trader(symbol_list):
    global position
    global remaining_cash
    global loss
    global profit
    global win
    global total_valuation
    global list_for_Risk
    global capital
    global buy_times
    global min_loss
    global max_profit
    
    
    for date in dates:
        symbols_in_date = """
        select distinct(name) from stockdatamonthly where date = '%s'
        """ % date
        symbols = pd.read_sql(symbols_in_date,engine)['name'].tolist()
        for symbol in symbol_list:
            if symbol in symbols:
                current_symbol = stock_equities[symbol]
                data_till_date = data_extract(current_symbol.dataframe,date)
                current_price = data_till_date.tail(1)['2. high'].values[0]
                current_symbol.current_price = current_price
                if len(data_till_date) == 1:
                    continue
                if current_symbol.bought == None:
                    
                    
                    if resist_condition(data_till_date):
                        current_symbol.resistance, current_symbol.resistance_date = resistance_cal(data_till_date)
                        
                    if current_symbol.resistance != None and support_condition(data_till_date, current_symbol.resistance):
                        current_symbol.support = support_cal(current_symbol.resistance_date, data_till_date)
                    
                    if current_symbol.support != None and current_symbol.resistance !=None and buy_condition(current_symbol.resistance, data_till_date):
                        training_inst = training_set_extractor(data_till_date, date)
                        training_inst = np.asarray(training_inst)
                        for_predict = np.append([tf.keras.utils.normalize(training_inst[0])], [tf.keras.utils.normalize(training_inst[1])])
                        if(model.predict([for_predict]) == 1):
                            buy_stocks(current_price, current_symbol, date)  
                            
                else:
                    if current_symbol.flag_for_wins == False and current_symbol.stop_order > current_symbol.bought:
                                win += 1
                                current_symbol.flag_for_wins = True
                        
                        
                    if current_symbol.stop_order > current_price:
                        
                        
                        current_symbol.stop_order = None
                        print("Selling ",position[symbol], "stocks of", symbol, " at price", current_price, "on date", date)
                        sold = current_price * position[symbol] - commission
                        profit_today = sold - current_symbol.bought * position[symbol]
                        
                        if profit_today > 0:                           
                            if current_symbol.flag_for_wins == False:
                                win += 1
                            current_symbol.flag_for_wins = False
                            
                        else:
                            loss += 1                           
                            current_symbol.flag_for_wins = False
                            
                        
                        profit += profit_today
                        
                        if profit < min_loss:
                            min_loss = profit
                        if profit > max_profit:
                            profit = profit_today
                            
                        
                        remaining_cash = remaining_cash + sold
                        del position[symbol]
                        current_symbol.bought = None
                        
                    else:
                        if resist_condition(data_till_date):
                            current_symbol.resistance, current_symbol.resistance_date = resistance_cal( data_till_date)
                        
                        if current_symbol.resistance and support_condition(data_till_date,current_symbol.resistance):
                            current_symbol.support = support_cal(current_symbol.resistance_date, data_till_date)
                        
                        if current_symbol.resistance != None and current_symbol.support != None and buy_condition(current_symbol.resistance, data_till_date):
                            current_symbol.stop_order = current_symbol.support * 0.97
                    
                        
    print("Win Percentage")            
    print((win/(loss + win))*100)
    print("Profit",profit)
    print("\n")

# %% [markdown]
# <h1> Helper functions for the strategy

# %%
def resistance_cal(data_resistance):

    highest_data = data_resistance[data_resistance['2. high'] == max(data_resistance['2. high'])]
    date = highest_data['date'].values[0]
    resistance = highest_data['2. high'].values[0]


    return round(resistance + 0.005,2), date                

def support_cal(resist_date, data_support):

    # data since the last resistance date until today's date.
    data_since_last_resistance = data_support.loc[data_support['date'] >= resist_date]
    # data variable here contains the row of the dataframe with the lowest value of '3. low' values
    data = data_since_last_resistance.loc[data_since_last_resistance['3. low']==min(data_since_last_resistance['3. low'])]
    # support here contains the lowest value of stock since last resistance date
    support = data['3. low'].values[0]


    # we return the support value and the date of the support value
    return support

def resist_condition(  data_resistance):

    recent_data = data_resistance.tail(2)   # Getting yesterday's and today's price
    yesterday_price = recent_data['3. low'].values[0]   # Yesterday's prices
    today_price = recent_data['3. low'].values[1]       # today's prices  


    if(today_price < yesterday_price):
        return True
    else:
        return False
    # If today's lowest price of the stock is less than yesterday's lowest price of the stock,
    # then Resistance condition is met

def support_condition(data_support, resist_passed):
    current_price = data_support.tail(1)['2. high'].values[0] # Today's price of the stock
    if(current_price > resist_passed):
        return True
    else:
        return False
    #If the current price of the stock is greater than the current resistance value that is passed then,
    # the support condition is met     

def buy_condition(resist, data):
    if resist < data.tail(1)['2. high'].values[0]:
        return True
    else:
        return False       

def data_extract(data, *args):
    if len(args) == 2:
        data = data.loc[data['date'] >= args[0]]
        data = data.loc[data['date'] <= args[1]]
    else:
        data = data.loc[data['date'] <= args[0]]
    return data

def training_set_extractor(data, date):
    past_five_months = data.tail(5)
    difference = abs(len(past_five_months['2. high'].tolist()) - 5)
    zeros_list = [0] * (difference)
    training_instance = [zeros_list[:], zeros_list[:], 'na']
        
    training_instance[0].extend(past_five_months['2. high'].tolist()[:])
    training_instance[1].extend(past_five_months['5. volume'].tolist()[:])
    return training_instance[:]
      

def buy_stocks(current_price, current_symbol, date):
    global position
    global remaining_cash
    global risk
    global commission
    
    quantity = (0.02 * remaining_cash) // (current_price - (current_symbol.support * 0.97))
              
    if quantity > 1:
        current_symbol.bought = current_price
        current_symbol.stop_order = current_symbol.support * 0.97
        remaining_cash = remaining_cash - commission - (quantity * current_price)
        position[current_symbol.symbol] = quantity
        print("Buying ", quantity, "stocks of ", current_symbol.symbol, "At price", current_symbol.bought, "on date", date)
    else:
        pass

# %%
automatic_trader(symbol_list)
# Out:
# Buying  62.0 stocks of  BDN At price 18.0 on date 2000-04-28
# Buying  28.0 stocks of  MDU At price 23.25 on date 2000-04-28
# Buying  87.0 stocks of  HT At price 5.75 on date 2000-05-31
# Buying  168.0 stocks of  GIM At price 6.25 on date 2000-06-30
# Buying  25.0 stocks of  UHT At price 19.12 on date 2000-06-30
# Buying  43.0 stocks of  INT At price 9.0 on date 2000-06-30
# Buying  73.0 stocks of  MHE At price 12.62 on date 2000-06-30
# Buying  9.0 stocks of  MSM At price 23.0 on date 2000-06-30
# Buying  78.0 stocks of  ANH At price 5.06 on date 2000-09-29
# Buying  3.0 stocks of  UHS At price 89.5 on date 2000-09-29
# Buying  29.0 stocks of  MCRI At price 6.063 on date 2000-09-29
# Buying  2.0 stocks of  PAYX At price 61.0 on date 2000-10-31
# Buying  4.0 stocks of  AEGN At price 38.12 on date 2000-11-30
# Buying  34.0 stocks of  IEP At price 10.31 on date 2001-01-31
# Buying  19.0 stocks of  BSD At price 14.94 on date 2001-01-31
# Buying  5.0 stocks of  RS At price 28.0 on date 2001-01-31
# Buying  2.0 stocks of  SFNC At price 34.5 on date 2001-05-31
# Buying  27.0 stocks of  AEMD At price 3.5 on date 2001-05-31
# Selling  3.0 stocks of UHS  at price 53.4 on date 2001-07-31
# Selling  28.0 stocks of MDU  at price 26.76 on date 2001-10-31
# Selling  4.0 stocks of AEGN  at price 21.05 on date 2001-10-31
# Buying  6.0 stocks of  NRCIB At price 13.42 on date 2002-01-31
# Selling  27.0 stocks of AEMD  at price 1.95 on date 2002-04-30
# Selling  2.0 stocks of PAYX  at price 27.09 on date 2002-08-30
# Selling  5.0 stocks of RS  at price 19.16 on date 2003-02-28
# Selling  2.0 stocks of SFNC  at price 21.51 on date 2003-06-30
# Buying  3.0 stocks of  RS At price 35.0 on date 2003-12-31
# Buying  12.0 stocks of  GLAD At price 23.71 on date 2004-01-30
# Buying  26.0 stocks of  BBK At price 15.32 on date 2004-02-27
# Selling  78.0 stocks of ANH  at price 12.18 on date 2004-05-28
# Buying  13.0 stocks of  PKOH At price 12.3 on date 2004-06-30
# Buying  38.0 stocks of  PFL At price 20.85 on date 2004-07-30
# Buying  6.0 stocks of  VUG At price 52.15 on date 2004-12-31
# Buying  6.0 stocks of  LKQ At price 20.92 on date 2004-12-31
# Buying  15.0 stocks of  GLV At price 22.5 on date 2005-01-31
# Selling  43.0 stocks of INT  at price 31.69 on date 2005-03-31
# Buying  5.0 stocks of  CCOI At price 13.5 on date 2005-04-29
# Selling  38.0 stocks of PFL  at price 19.25 on date 2005-06-30
# Buying  10.0 stocks of  VBK At price 54.73 on date 2005-06-30
# Buying  19.0 stocks of  EVT At price 22.5 on date 2005-08-31
# Buying  5.0 stocks of  CMCO At price 28.44 on date 2006-01-31
# Selling  6.0 stocks of LKQ  at price 22.47 on date 2006-02-28
# Buying  13.0 stocks of  BOE At price 25.4 on date 2006-02-28
# Buying  8.0 stocks of  NAK At price 9.24 on date 2006-06-30
# Buying  2.0 stocks of  UAA At price 43.5 on date 2006-06-30
# Selling  3.0 stocks of RS  at price 33.45 on date 2006-09-29
# Buying  3.0 stocks of  AMP At price 52.64 on date 2006-10-31
# Buying  26.0 stocks of  LSBK At price 11.51 on date 2006-10-31
# Buying  9.0 stocks of  RFV At price 33.62 on date 2006-10-31
# Buying  10.0 stocks of  GYC At price 23.99 on date 2007-01-31
# Buying  4.0 stocks of  MDYG At price 65.81 on date 2007-02-28
# Buying  3.0 stocks of  WNS At price 35.83 on date 2007-02-28
# Selling  19.0 stocks of BSD  at price 17.4 on date 2007-06-29
# Selling  62.0 stocks of BDN  at price 28.88 on date 2007-07-31
# Selling  3.0 stocks of WNS  at price 25.47 on date 2007-08-31
# Selling  73.0 stocks of MHE  at price 12.34 on date 2007-09-28
# Buying  4.0 stocks of  UAL At price 51.6 on date 2007-10-31
# Buying  3.0 stocks of  LKQ At price 41.79 on date 2007-10-31
# Buying  4.0 stocks of  IEO At price 66.36 on date 2007-10-31
# Selling  26.0 stocks of BBK  at price 15.85 on date 2007-12-31
# Selling  26.0 stocks of LSBK  at price 9.25 on date 2007-12-31
# Selling  9.0 stocks of RFV  at price 33.53 on date 2008-01-31
# Selling  12.0 stocks of GLAD  at price 19.87 on date 2008-01-31
# Selling  5.0 stocks of CCOI  at price 20.7 on date 2008-02-29
# Buying  3.0 stocks of  TWM At price 86.35 on date 2008-02-29
# Selling  34.0 stocks of IEP  at price 102.25 on date 2008-03-31
# Selling  19.0 stocks of EVT  at price 24.34 on date 2008-03-31
# Selling  2.0 stocks of UAA  at price 39.95 on date 2008-03-31
# Selling  4.0 stocks of UAL  at price 30.58 on date 2008-03-31
# Selling  8.0 stocks of NAK  at price 10.25 on date 2008-05-30
# Selling  3.0 stocks of AMP  at price 47.98 on date 2008-06-30
# Selling  10.0 stocks of GYC  at price 20.25 on date 2008-07-31
# Selling  15.0 stocks of GLV  at price 19.45 on date 2008-08-29
# Selling  4.0 stocks of MDYG  at price 53.52 on date 2008-10-31
# Selling  6.0 stocks of VUG  at price 51.76 on date 2008-10-31
# Buying  52.0 stocks of  SRCI At price 4.0 on date 2008-10-31
# Selling  87.0 stocks of HT  at price 7.25 on date 2008-10-31
# Selling  3.0 stocks of LKQ  at price 16.9 on date 2008-10-31
# Selling  13.0 stocks of BOE  at price 18.09 on date 2008-10-31
# Selling  29.0 stocks of MCRI  at price 11.47 on date 2008-10-31
# Selling  10.0 stocks of VBK  at price 59.24 on date 2008-10-31
# Selling  5.0 stocks of CMCO  at price 14.6 on date 2008-11-28
# Selling  4.0 stocks of IEO  at price 41.41 on date 2008-12-31
# Selling  13.0 stocks of PKOH  at price 6.63 on date 2009-01-30
# Selling  9.0 stocks of MSM  at price 32.17 on date 2009-03-31
# Selling  3.0 stocks of TWM  at price 52.05 on date 2009-05-29
# Selling  6.0 stocks of NRCIB  at price 21.95 on date 2010-01-29
# Buying  19.0 stocks of  TCCO At price 13.15 on date 2010-03-31
# Buying  15.0 stocks of  MSM At price 59.12 on date 2010-10-29
# Buying  4.0 stocks of  VBK At price 79.41 on date 2010-12-31
# Buying  12.0 stocks of  NRCIB At price 35.8 on date 2011-04-29
# Selling  19.0 stocks of TCCO  at price 8.0658 on date 2011-08-31
# Buying  149.0 stocks of  FBNK At price 11.38 on date 2011-09-30
# Buying  4.0 stocks of  VUG At price 69.44 on date 2012-02-29
# Buying  8.0 stocks of  CURE At price 44.7 on date 2012-03-30
# Buying  3.0 stocks of  UAA At price 102.86 on date 2012-04-30
# Selling  168.0 stocks of GIM  at price 9.7 on date 2012-05-31
# Buying  7.0 stocks of  WMT At price 66.66 on date 2012-05-31
# Selling  3.0 stocks of UAA  at price 58.71 on date 2012-08-31
# Buying  19.0 stocks of  MHE At price 16.69 on date 2012-10-31
# Buying  2.0 stocks of  AMP At price 75.14 on date 2013-03-28
# Buying  17.0 stocks of  LSBK At price 14.69 on date 2013-03-28
# Buying  5.0 stocks of  RFV At price 43.239 on date 2013-03-28
# Buying  4.0 stocks of  PKOH At price 37.59 on date 2013-04-30
# Buying  17.0 stocks of  XGTI At price 9.5 on date 2013-04-30
# Buying  11.0 stocks of  GYC At price 25.0 on date 2013-05-31
# Buying  11.0 stocks of  MDYG At price 101.8548 on date 2013-05-31
# Selling  12.0 stocks of NRCIB  at price 46.52 on date 2013-06-28
# Selling  8.0 stocks of CURE  at price 58.21 on date 2013-09-30
# Selling  25.0 stocks of UHT  at price 42.47 on date 2013-09-30
# Buying  4.0 stocks of  CCOI At price 39.05 on date 2013-11-29
# Buying  2.0 stocks of  UAA At price 108.72 on date 2014-01-31
# Buying  2.0 stocks of  IEO At price 92.0465 on date 2014-04-30
# Buying  6.0 stocks of  SFNC At price 43.22 on date 2014-06-30
# Buying  3.0 stocks of  UAL At price 52.45 on date 2014-09-30
# Buying  22.0 stocks of  APDN At price 7.0 on date 2014-11-28
# Buying  2.0 stocks of  CURE At price 133.0 on date 2014-11-28
# Buying  67.0 stocks of  MRDN At price 2.49 on date 2014-12-31
# Buying  4.0 stocks of  UHS At price 121.95 on date 2015-03-31
# Selling  15.0 stocks of MSM  at price 74.13 on date 2015-03-31
# Buying  10.0 stocks of  AEMD At price 15.25 on date 2015-04-30
# Selling  2.0 stocks of CURE  at price 42.87 on date 2015-06-30
# Buying  6.0 stocks of  HT At price 28.6 on date 2015-07-31
# Selling  4.0 stocks of PKOH  at price 35.79 on date 2015-09-30
# Selling  7.0 stocks of WMT  at price 67.01 on date 2015-09-30
# Selling  2.0 stocks of AMP  at price 113.01 on date 2015-09-30
# Selling  4.0 stocks of VBK  at price 124.99 on date 2015-10-30
# Selling  5.0 stocks of RFV  at price 47.46 on date 2016-01-29
# Selling  52.0 stocks of SRCI  at price 6.5 on date 2016-02-29
# Selling  17.0 stocks of XGTI  at price 0.181 on date 2016-03-31
# Buying  67.0 stocks of  SOJA At price 27.7 on date 2016-03-31
# Buying  14.0 stocks of  ONEO At price 61.0 on date 2016-04-29
# Buying  24.0 stocks of  DRIO At price 5.825 on date 2016-04-29
# Buying  4.0 stocks of  KHC At price 86.66 on date 2016-05-31
# Buying  236.0 stocks of  BHACU At price 10.23 on date 2016-06-30
# Selling  2.0 stocks of UAA  at price 40.28 on date 2016-06-30
# Buying  2.0 stocks of  UHT At price 63.35 on date 2016-08-31
# Buying  8.0 stocks of  LBDC At price 19.4 on date 2016-09-30
# Buying  21.0 stocks of  SUPV At price 15.35 on date 2016-10-31
# Buying  4.0 stocks of  RFV At price 65.03 on date 2016-12-30
# Buying  17.0 stocks of  EYLD At price 27.57 on date 2016-12-30
# Buying  4.0 stocks of  PAYX At price 62.17 on date 2017-01-31
# Buying  4.0 stocks of  Z At price 40.29 on date 2017-04-28
# Buying  4.0 stocks of  DAX At price 29.54 on date 2017-05-31
# Selling  8.0 stocks of LBDC  at price 18.25 on date 2017-09-29
# Buying  2.0 stocks of  VBK At price 152.7 on date 2017-09-29
# Buying  2.0 stocks of  CWEB At price 58.0041 on date 2017-11-30
# Buying  3.0 stocks of  CMCO At price 44.55 on date 2018-01-31
# Buying  2.0 stocks of  NBLX At price 57.98 on date 2018-01-31
# Selling  6.0 stocks of SFNC  at price 30.9 on date 2018-03-29
# Buying  3.0 stocks of  WNS At price 48.26 on date 2018-03-29
# Selling  4.0 stocks of KHC  at price 67.989 on date 2018-03-29
# Buying  14.0 stocks of  INDU At price 11.74 on date 2018-04-30
# Buying  4.0 stocks of  MBIN At price 26.47 on date 2018-05-31
# Buying  2.0 stocks of  RCKT At price 24.28 on date 2018-06-29
# Selling  21.0 stocks of SUPV  at price 20.31 on date 2018-06-29
# Buying  5.0 stocks of  CBRE At price 49.89 on date 2018-07-13
# Selling  11.0 stocks of MDYG  at price 55.72 on date 2018-07-13
# Win Percentage
# 51.94805194805194
# Profit -766.4298000000001

# %%
print("Remaining Cash ::" , remaining_cash)
# Out:
# Remaining Cash :: 2207.3971999999885

# %%
current_profit = 0
for key in position:
    current_profit = position[key] * (stock_equities[key].current_price - stock_equities[key].bought)
    remaining_cash += position[key] * stock_equities[key].current_price
    profit += current_profit
    
    if current_profit > 0:
        win += 1
    else:
        loss += 1
    
    if profit > max_profit:
        max_profit = profit
    
    if profit < min_loss:
        min_loss = profit
    
    
print("Maximum Profit is ", max_profit)
print("Minimum Loss is ", min_loss)
print("Profit", profit)
print("Remaining cash ", remaining_cash)
print("Win Percentage")            
print((win/(loss + win))*100)
# Out:
# Maximum Profit is  2717.3673999999996
# Minimum Loss is  -766.4298000000001
# Profit 2695.5371999999998
# Remaining cash  18146.49539999999
# Win Percentage
# 52.293577981651374
