# %%
import pandas as pd
import time
from datetime import datetime
from alpha_vantage.timeseries import TimeSeries
import random
import urllib
import sqlalchemy
import matplotlib.pyplot as plt
import sys
import tensorflow as tf
import keras
import numpy as np

position = {}
remaining_cash = 10000.00
capital = 10000.00
loss = 0
win = 0
total_valuation = 0    
profit = 0
commission = 5
buy_times = 0
min_loss = 0
max_profit = 0

# %%
params = urllib.parse.quote("DRIVER={ODBC Driver 13 for SQL Server};SERVER=localhost;DATABASE=StocksDMW;Trusted_Connection=yes")
engine = sqlalchemy.create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)

# %%
symbols = """
select distinct(name) from stockdataweekly order by name
"""
symbol_list = pd.read_sql(symbols, engine)

# %%
symbol_list = symbol_list['name'].tolist()

# %% [markdown]
# <h1> Instantation of variables

# %%
class equity():
    bought = None
    support = None
    resistance = None
    resistance_date = None
    stop_order = None
    times_bought = 0
    symbol = None
    dataframe = None
    current_price = None
   
    flag_for_wins = False
    
    def __init__(self, name):
        self.symbol = name
      

sql1= """
select distinct(name) from stockdataweekly order by name
"""
names = pd.read_sql(sql1,engine)['name'].tolist()

stock_equities = {}
for name in names:
    stock_equities[name] = equity(name)

# %% [markdown]
# <h1> Updating resources

# %%
cursor = len(symbol_list)
percent = cursor // 100


counter = 0
percentage = 0
for symbol in symbol_list:
    if(counter % percent == 0 ):
        print(percentage , "% done")
        percentage += 1
    symbol_data = """
    select * from stockdataweekly where name = '%s'
    """ % symbol
    counter += 1
    stock_equities[symbol].dataframe = pd.read_sql(symbol_data,engine)
# Out:
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done

# %%
sql_dates = """
select distinct(date) from stockdataweekly order by date
"""
dates = pd.read_sql(sql_dates, engine)['date'].tolist()

# %% [markdown]
# <h1> Loading KNN Model

# %%
import pickle

pickle_in = open("KNN-ModelWeekly63.pickle","rb")
model = pickle.load(pickle_in)

# %% [markdown]
# <h1> Trading strategy with the training sets generation

# %%
def automatic_trader(symbol_list):
    global position
    global remaining_cash
    global loss
    global profit
    global win
    global total_valuation
    global list_for_Risk
    global capital
    global buy_times
    global min_loss
    global max_profit
    
    
    for date in dates:
        symbols_in_date = """
        select distinct(name) from stockdataweekly where date = '%s'
        """ % date
        symbols = pd.read_sql(symbols_in_date,engine)['name'].tolist()
        for symbol in symbol_list:
            if symbol in symbols:
                current_symbol = stock_equities[symbol]
                data_till_date = data_extract(current_symbol.dataframe,date)
                current_price = data_till_date.tail(1)['2. high'].values[0]
                current_symbol.current_price = current_price
                if len(data_till_date) == 1:
                    continue
                if current_symbol.bought == None:
                    
                    
                    if resist_condition(data_till_date):
                        current_symbol.resistance, current_symbol.resistance_date = resistance_cal(data_till_date)
                        
                    if current_symbol.resistance != None and support_condition(data_till_date, current_symbol.resistance):
                        current_symbol.support = support_cal(current_symbol.resistance_date, data_till_date)
                    
                    if current_symbol.support != None and current_symbol.resistance !=None and buy_condition(current_symbol.resistance, data_till_date):
                        training_inst = training_set_extractor(data_till_date, date)
                        training_inst = np.asarray(training_inst)
                        for_predict = np.append([tf.keras.utils.normalize(training_inst[0])], [tf.keras.utils.normalize(training_inst[1])])
                        if(model.predict([for_predict]) == 1):
                            buy_stocks(current_price, current_symbol, date)  
                            
                else:
                    if current_symbol.flag_for_wins == False and current_symbol.stop_order > current_symbol.bought:
                                win += 1
                                current_symbol.flag_for_wins = True
                        
                        
                    if current_symbol.stop_order > current_price:
                        
                        
                        current_symbol.stop_order = None
                        print("Selling ",position[symbol], "stocks of", symbol, " at price", current_price, "on date", date)
                        sold = current_price * position[symbol] - commission
                        profit_today = sold - current_symbol.bought * position[symbol]
                        
                        if profit_today > 0:                           
                            if current_symbol.flag_for_wins == False:
                                win += 1
                            current_symbol.flag_for_wins = False
                            
                        else:
                            loss += 1                           
                            current_symbol.flag_for_wins = False
                            
                        
                        profit += profit_today
                        
                        if profit < min_loss:
                            min_loss = profit
                        if profit > max_profit:
                            profit = profit_today
                            
                        
                        remaining_cash = remaining_cash + sold
                        del position[symbol]
                        current_symbol.bought = None
                        
                    else:
                        if resist_condition(data_till_date):
                            current_symbol.resistance, current_symbol.resistance_date = resistance_cal( data_till_date)
                        
                        if current_symbol.resistance and support_condition(data_till_date,current_symbol.resistance):
                            current_symbol.support = support_cal(current_symbol.resistance_date, data_till_date)
                        
                        if current_symbol.resistance != None and current_symbol.support != None and buy_condition(current_symbol.resistance, data_till_date):
                            current_symbol.stop_order = current_symbol.support * 0.97
                    
                        
    print("Win Percentage")            
    print((win/(loss + win))*100)
    print("Profit",profit)
    print("\n")

# %% [markdown]
# <h1> Helper functions for the strategy

# %%
def resistance_cal(data_resistance):

    highest_data = data_resistance[data_resistance['2. high'] == max(data_resistance['2. high'])]
    date = highest_data['date'].values[0]
    resistance = highest_data['2. high'].values[0]


    return round(resistance + 0.005,2), date                

def support_cal(resist_date, data_support):

    # data since the last resistance date until today's date.
    data_since_last_resistance = data_support.loc[data_support['date'] >= resist_date]
    # data variable here contains the row of the dataframe with the lowest value of '3. low' values
    data = data_since_last_resistance.loc[data_since_last_resistance['3. low']==min(data_since_last_resistance['3. low'])]
    # support here contains the lowest value of stock since last resistance date
    support = data['3. low'].values[0]


    # we return the support value and the date of the support value
    return support

def resist_condition(  data_resistance):

    recent_data = data_resistance.tail(2)   # Getting yesterday's and today's price
    yesterday_price = recent_data['3. low'].values[0]   # Yesterday's prices
    today_price = recent_data['3. low'].values[1]       # today's prices  


    if(today_price < yesterday_price):
        return True
    else:
        return False
    # If today's lowest price of the stock is less than yesterday's lowest price of the stock,
    # then Resistance condition is met

def support_condition(data_support, resist_passed):
    current_price = data_support.tail(1)['2. high'].values[0] # Today's price of the stock
    if(current_price > resist_passed):
        return True
    else:
        return False
    #If the current price of the stock is greater than the current resistance value that is passed then,
    # the support condition is met     

def buy_condition(resist, data):
    if resist < data.tail(1)['2. high'].values[0]:
        return True
    else:
        return False       

def data_extract(data, *args):
    if len(args) == 2:
        data = data.loc[data['date'] >= args[0]]
        data = data.loc[data['date'] <= args[1]]
    else:
        data = data.loc[data['date'] <= args[0]]
    return data

def training_set_extractor(data, date):
    past_ten_weeks = data.tail(10)
    difference = abs(len(past_ten_weeks['2. high'].tolist()) - 10)
    zeros_list = [0] * (difference)
    training_instance = [zeros_list[:], zeros_list[:], 'na']
        
    training_instance[0].extend(past_ten_weeks['2. high'].tolist()[:])
    training_instance[1].extend(past_ten_weeks['5. volume'].tolist()[:])
    return training_instance[:]   

def buy_stocks(current_price, current_symbol, date):
    global position
    global remaining_cash
    global risk
    global commission
    
    quantity = (0.02 * remaining_cash) // (current_price - (current_symbol.support * 0.97))
              
    if quantity > 1:
        current_symbol.bought = current_price
        current_symbol.stop_order = current_symbol.support * 0.97
        remaining_cash = remaining_cash - commission - (quantity * current_price)
        position[current_symbol.symbol] = quantity
        print("Buying ", quantity, "stocks of ", current_symbol.symbol, "At price", current_symbol.bought, "on date", date)
    else:
        pass

# %%
automatic_trader(symbol_list)
# Out:
# Buying  122.0 stocks of  ICAD At price 3.81 on date 2000-01-28
# Buying  304.0 stocks of  BIF At price 8.75 on date 2000-02-04
# Buying  11.0 stocks of  ISCA At price 52.75 on date 2000-02-04
# Buying  12.0 stocks of  DGX At price 40.38 on date 2000-03-10
# Buying  9.0 stocks of  CBK At price 25.44 on date 2000-03-31
# Buying  182.0 stocks of  OIA At price 8.188 on date 2000-04-07
# Buying  4.0 stocks of  CVS At price 44.5 on date 2000-04-07
# Selling  122.0 stocks of ICAD  at price 2.25 on date 2000-04-14
# Buying  10.0 stocks of  EQR At price 45.5 on date 2000-04-28
# Buying  17.0 stocks of  DCI At price 24.94 on date 2000-05-19
# Buying  5.0 stocks of  CMA At price 50.56 on date 2000-05-26
# Selling  17.0 stocks of DCI  at price 20.69 on date 2000-06-30
# Buying  6.0 stocks of  MBT At price 32.0 on date 2000-09-01
# Buying  10.0 stocks of  GATX At price 45.19 on date 2000-09-15
# Selling  5.0 stocks of CMA  at price 50.0 on date 2000-11-24
# Buying  7.0 stocks of  UNT At price 19.44 on date 2000-12-29
# Selling  10.0 stocks of GATX  at price 41.83 on date 2001-04-12
# Buying  4.0 stocks of  SALM At price 21.6 on date 2001-05-18
# Buying  6.0 stocks of  SWM At price 21.56 on date 2001-05-18
# Selling  11.0 stocks of ISCA  at price 40.14 on date 2001-12-07
# Buying  30.0 stocks of  BOOM At price 4.19 on date 2001-12-14
# Selling  304.0 stocks of BIF  at price 7.9 on date 2001-12-28
# Buying  12.0 stocks of  ITIC At price 18.74 on date 2002-03-15
# Buying  51.0 stocks of  PW At price 8.35 on date 2002-03-15
# Selling  10.0 stocks of EQR  at price 24.35 on date 2002-11-01
# Selling  4.0 stocks of CVS  at price 25.79 on date 2002-12-20
# Buying  11.0 stocks of  PETS At price 9.03 on date 2003-10-31
# Buying  8.0 stocks of  PH At price 63.3 on date 2004-10-15
# Buying  87.0 stocks of  BIOC At price 3.5 on date 2005-07-08
# Buying  20.0 stocks of  PAY At price 18.64 on date 2005-07-22
# Buying  3.0 stocks of  ISCA At price 54.22 on date 2005-11-04
# Buying  61.0 stocks of  PFM At price 15.17 on date 2005-11-18
# Buying  4.0 stocks of  AXL At price 17.5 on date 2006-06-30
# Buying  10.0 stocks of  KRNY At price 15.01 on date 2006-06-30
# Selling  6.0 stocks of SWM  at price 20.25 on date 2006-08-04
# Buying  5.0 stocks of  FIX At price 12.23 on date 2006-09-29
# Buying  28.0 stocks of  CEI At price 20.04 on date 2007-01-19
# Buying  15.0 stocks of  CYCCP At price 7.15 on date 2007-02-23
# Buying  6.0 stocks of  BREW At price 7.19 on date 2007-04-20
# Buying  12.0 stocks of  KED At price 27.45 on date 2007-04-27
# Selling  28.0 stocks of CEI  at price 2.35 on date 2007-05-11
# Buying  2.0 stocks of  PAF At price 60.76 on date 2007-10-19
# Selling  12.0 stocks of KED  at price 23.76 on date 2007-11-23
# Selling  2.0 stocks of PAF  at price 54.8 on date 2008-02-01
# Selling  4.0 stocks of SALM  at price 2.74 on date 2008-06-06
# Selling  7.0 stocks of UNT  at price 68.03 on date 2008-08-08
# Selling  12.0 stocks of DGX  at price 46.57 on date 2009-03-13
# Selling  10.0 stocks of KRNY  at price 9.4 on date 2009-03-13
# Buying  116.0 stocks of  HBP At price 0.65 on date 2009-04-17
# Selling  8.0 stocks of PH  at price 48.45 on date 2009-06-05
# Buying  2.0 stocks of  SWM At price 43.488 on date 2009-08-07
# Selling  9.0 stocks of CBK  at price 8.25 on date 2009-09-25
# Selling  116.0 stocks of HBP  at price 0.75 on date 2009-11-27
# Buying  8.0 stocks of  LEA At price 73.73 on date 2010-01-08
# Selling  15.0 stocks of CYCCP  at price 4.1 on date 2010-01-29
# Selling  3.0 stocks of ISCA  at price 26.35 on date 2010-02-05
# Selling  61.0 stocks of PFM  at price 12.98 on date 2010-08-13
# Buying  43.0 stocks of  WMLP At price 19.95 on date 2010-10-01
# Selling  182.0 stocks of OIA  at price 6.56 on date 2010-11-26
# Buying  13.0 stocks of  PDM At price 21.0 on date 2010-12-17
# Selling  6.0 stocks of MBT  at price 16.9 on date 2011-08-19
# Buying  9.0 stocks of  DCI At price 67.85 on date 2011-11-11
# Buying  58.0 stocks of  GZT At price 9.98 on date 2012-02-17
# Selling  43.0 stocks of WMLP  at price 9.08 on date 2012-03-09
# Buying  8.0 stocks of  OMER At price 10.88 on date 2012-03-16
# Buying  47.0 stocks of  HBP At price 1.55 on date 2012-03-23
# Buying  23.0 stocks of  FSZ At price 31.88 on date 2012-03-23
# Buying  35.0 stocks of  ONVO At price 3.2 on date 2012-05-04
# Selling  23.0 stocks of FSZ  at price 29.224 on date 2012-05-18
# Buying  25.0 stocks of  QDYN At price 28.18 on date 2013-03-22
# Buying  18.0 stocks of  FMF At price 50.29 on date 2013-10-18
# Buying  5.0 stocks of  EVHC At price 30.39 on date 2013-11-29
# Buying  2.0 stocks of  UPV At price 51.71 on date 2014-01-17
# Buying  3.0 stocks of  GATX At price 66.59 on date 2014-03-14
# Buying  4.0 stocks of  BNDX At price 50.57 on date 2014-03-21
# Buying  2.0 stocks of  SMLV At price 73.402 on date 2014-03-21
# Selling  2.0 stocks of SWM  at price 40.5 on date 2014-04-17
# Buying  2.0 stocks of  KED At price 34.48 on date 2014-05-02
# Buying  2.0 stocks of  DBMX At price 24.59 on date 2014-05-09
# Selling  9.0 stocks of DCI  at price 40.87 on date 2014-08-22
# Selling  25.0 stocks of QDYN  at price 33.8 on date 2014-10-17
# Buying  5.0 stocks of  QDYN At price 36.822 on date 2014-11-21
# Buying  4.0 stocks of  RESN At price 12.2399 on date 2015-01-02
# Buying  6.0 stocks of  BBP At price 30.11 on date 2015-02-20
# Buying  4.0 stocks of  JRVR At price 26.4 on date 2015-07-10
# Selling  4.0 stocks of RESN  at price 5.75 on date 2015-09-04
# Buying  10.0 stocks of  AGGY At price 49.97 on date 2015-10-16
# Buying  2.0 stocks of  OPNT At price 10.1 on date 2016-01-29
# Selling  6.0 stocks of BBP  at price 24.72 on date 2016-02-05
# Selling  2.0 stocks of UPV  at price 38.21 on date 2016-03-18
# Buying  2.0 stocks of  FCOM At price 29.345 on date 2016-03-24
# Buying  3.0 stocks of  DEWJ At price 23.8917 on date 2016-04-15
# Buying  8.0 stocks of  CDEV At price 10.59 on date 2016-06-17
# Selling  3.0 stocks of GATX  at price 47.1 on date 2016-06-24
# Selling  51.0 stocks of PW  at price 6.99 on date 2016-06-24
# Buying  2.0 stocks of  FNDB At price 31.11 on date 2016-07-22
# Buying  3.0 stocks of  MEDP At price 31.0 on date 2016-09-09
# Selling  58.0 stocks of GZT  at price 9.43 on date 2016-12-02
# Selling  2.0 stocks of OPNT  at price 6.37 on date 2016-12-30
# Buying  16.0 stocks of  HDAW At price 25.07 on date 2017-01-06
# Selling  87.0 stocks of BIOC  at price 0.96 on date 2017-01-06
# Buying  4.0 stocks of  LSVX At price 29.67 on date 2017-01-27
# Buying  7.0 stocks of  SBBC At price 26.514 on date 2017-07-21
# Buying  9.0 stocks of  OXLCM At price 25.75 on date 2018-04-20
# Buying  5.0 stocks of  PEY At price 17.47 on date 2018-06-01
# Selling  35.0 stocks of ONVO  at price 1.42 on date 2018-07-06
# Win Percentage
# 38.18181818181819
# Profit -3533.249600000001

# %%
print("Remaining Cash ::" , remaining_cash)
# Out:
# Remaining Cash :: 398.4132999999984

# %%
current_profit = 0
for key in position:
    current_profit = position[key] * (stock_equities[key].current_price - stock_equities[key].bought)
    remaining_cash += position[key] * stock_equities[key].current_price
    profit += current_profit
    
    if current_profit > 0:
        win += 1
    else:
        loss += 1
    
    if profit > max_profit:
        max_profit = profit
    
    if profit < min_loss:
        min_loss = profit
    
    
print("Maximum Profit is ", max_profit)
print("Minimum Loss is ", min_loss)
print("Profit", profit)
print("Remaining cash ", remaining_cash)
print("Win Percentage")            
print((win/(loss + win))*100)
# Out:
# Maximum Profit is  2001.1768999999997
# Minimum Loss is  -3533.249600000001
# Profit 1938.9360999999997
# Remaining cash  11598.936099999999
# Win Percentage
# 49.411764705882355
