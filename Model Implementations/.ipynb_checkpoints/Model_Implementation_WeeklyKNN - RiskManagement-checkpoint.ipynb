# %%
import pandas as pd
import time
from datetime import datetime
from alpha_vantage.timeseries import TimeSeries
import random
import urllib
import sqlalchemy
import matplotlib.pyplot as plt
import sys
import tensorflow as tf
import keras
import numpy as np

position = {}
remaining_cash = 10000.00
capital = 10000.00
loss = 0
win = 0
total_valuation = 0    
profit = 0
commission = 5
buy_times = 0
min_loss = 0
max_profit = 0
risk = 0 # number of stocks currently in position

# %%
params = urllib.parse.quote("DRIVER={ODBC Driver 13 for SQL Server};SERVER=localhost;DATABASE=StocksDMW;Trusted_Connection=yes")
engine = sqlalchemy.create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)

# %%
symbols = """
select distinct(name) from stockdataweekly order by name
"""
symbol_list = pd.read_sql(symbols, engine)

# %%
symbol_list = symbol_list['name'].tolist()

# %% [markdown]
# <h1> Instantation of variables

# %%
class equity():
    bought = None
    support = None
    resistance = None
    resistance_date = None
    stop_order = None
    times_bought = 0
    symbol = None
    dataframe = None
    current_price = None
   
    flag_for_wins = False
    
    def __init__(self, name):
        self.symbol = name
      

sql1= """
select distinct(name) from stockdataweekly order by name
"""
names = pd.read_sql(sql1,engine)['name'].tolist()

stock_equities = {}
for name in names:
    stock_equities[name] = equity(name)

# %% [markdown]
# <h1> Updating resources

# %%
cursor = len(symbol_list)
percent = cursor // 100


counter = 0
percentage = 0
for symbol in symbol_list:
    if(counter % percent == 0 ):
        print(percentage , "% done")
        percentage += 1
    symbol_data = """
    select * from stockdataweekly where name = '%s'
    """ % symbol
    counter += 1
    stock_equities[symbol].dataframe = pd.read_sql(symbol_data,engine)
# Out:
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done

# %%
sql_dates = """
select distinct(date) from stockdataweekly order by date
"""
dates = pd.read_sql(sql_dates, engine)['date'].tolist()

# %% [markdown]
# <h1> Loading KNN Model

# %%
import pickle

pickle_in = open("KNN-ModelWeekly63.pickle","rb")
model = pickle.load(pickle_in)

# %% [markdown]
# <h1> Trading strategy with the training sets generation

# %%
def automatic_trader(symbol_list):
    global position
    global remaining_cash
    global loss
    global profit
    global win
    global min_loss
    global max_profit
    global risk
    
    for date in dates:
        symbols_in_date = """
        select distinct(name) from stockdataweekly where date = '%s'
        """ % date
        symbols = pd.read_sql(symbols_in_date,engine)['name'].tolist()
        for symbol in symbol_list:
            if symbol in symbols:
                current_symbol = stock_equities[symbol]
                data_till_date = data_extract(current_symbol.dataframe,date)
                current_price = data_till_date.tail(1)['2. high'].values[0]
                current_symbol.current_price = current_price
                if len(data_till_date) == 1:
                    continue
                if current_symbol.bought == None:
                    
                    
                    if resist_condition(data_till_date):
                        current_symbol.resistance, current_symbol.resistance_date = resistance_cal(data_till_date)
                        
                    if current_symbol.resistance != None and support_condition(data_till_date, current_symbol.resistance):
                        current_symbol.support = support_cal(current_symbol.resistance_date, data_till_date)
                    
                    if current_symbol.support != None and current_symbol.resistance !=None and buy_condition(current_symbol.resistance, data_till_date):
                        training_inst = training_set_extractor(data_till_date, date)
                        training_inst = np.asarray(training_inst)
                        for_predict = np.append([tf.keras.utils.normalize(training_inst[0])], [tf.keras.utils.normalize(training_inst[1])])
                        if(model.predict([for_predict]) == 1):
                            buy_stocks(current_price, current_symbol, date)                         
                            
                else:
                    if current_symbol.flag_for_wins == False and current_symbol.stop_order > current_symbol.bought:
                                win += 1
                                current_symbol.flag_for_wins = True
                                risk = risk - 1
                        
                        
                    if current_symbol.stop_order > current_price:
                        risk = risk - 1
                        
                        current_symbol.stop_order = None
                        print("Selling ",position[symbol], "stocks of", symbol, " at price", current_price, "on date", date)
                        sold = current_price * position[symbol] - commission
                        profit_today = sold - current_symbol.bought * position[symbol]
                        
                        if profit_today > 0:                           
                            if current_symbol.flag_for_wins == False:
                                win += 1
                            current_symbol.flag_for_wins = False
                            
                        else:
                            loss += 1                           
                            current_symbol.flag_for_wins = False
                            
                        if profit_today < min_loss:
                            min_loss = profit_today
                        if profit_today > max_profit:
                            max_profit = profit_today
                            
                        profit += profit_today
                        remaining_cash = remaining_cash + sold
                        del position[symbol]
                        current_symbol.bought = None
                        
                    else:
                        if resist_condition(data_till_date):
                            current_symbol.resistance, current_symbol.resistance_date = resistance_cal( data_till_date)
                        
                        if current_symbol.resistance and support_condition(data_till_date,current_symbol.resistance):
                            current_symbol.support = support_cal(current_symbol.resistance_date, data_till_date)
                        
                        if current_symbol.resistance != None and current_symbol.support != None and buy_condition(current_symbol.resistance, data_till_date):
                            current_symbol.stop_order = current_symbol.support * 0.97
                    
                        
    print("Win Percentage")            
    print((win/(loss + win))*100)
    print("Profit",profit)
    print("\n")

# %% [markdown]
# <h1> Helper functions for the strategy

# %%
def resistance_cal(data_resistance):

    highest_data = data_resistance[data_resistance['2. high'] == max(data_resistance['2. high'])]
    date = highest_data['date'].values[0]
    resistance = highest_data['2. high'].values[0]


    return round(resistance + 0.005,2), date                

def support_cal(resist_date, data_support):

    # data since the last resistance date until today's date.
    data_since_last_resistance = data_support.loc[data_support['date'] >= resist_date]
    # data variable here contains the row of the dataframe with the lowest value of '3. low' values
    data = data_since_last_resistance.loc[data_since_last_resistance['3. low']==min(data_since_last_resistance['3. low'])]
    # support here contains the lowest value of stock since last resistance date
    support = data['3. low'].values[0]


    # we return the support value and the date of the support value
    return support

def resist_condition(  data_resistance):

    recent_data = data_resistance.tail(2)   # Getting yesterday's and today's price
    yesterday_price = recent_data['3. low'].values[0]   # Yesterday's prices
    today_price = recent_data['3. low'].values[1]       # today's prices  


    if(today_price < yesterday_price):
        return True
    else:
        return False
    # If today's lowest price of the stock is less than yesterday's lowest price of the stock,
    # then Resistance condition is met

def support_condition(data_support, resist_passed):
    current_price = data_support.tail(1)['2. high'].values[0] # Today's price of the stock
    if(current_price > resist_passed):
        return True
    else:
        return False
    #If the current price of the stock is greater than the current resistance value that is passed then,
    # the support condition is met     

def buy_condition(resist, data):
    if resist < data.tail(1)['2. high'].values[0]:
        return True
    else:
        return False       

def data_extract(data, *args):
    if len(args) == 2:
        data = data.loc[data['date'] >= args[0]]
        data = data.loc[data['date'] <= args[1]]
    else:
        data = data.loc[data['date'] <= args[0]]
    return data

def training_set_extractor(data, date):
    past_ten_weeks = data.tail(10)
    difference = abs(len(past_ten_weeks['2. high'].tolist()) - 10)
    zeros_list = [0] * (difference)
    training_instance = [zeros_list[:], zeros_list[:], 'na']
        
    training_instance[0].extend(past_ten_weeks['2. high'].tolist()[:])
    training_instance[1].extend(past_ten_weeks['5. volume'].tolist()[:])
    return training_instance[:]   

def buy_stocks(current_price, current_symbol, date):
    global position
    global remaining_cash
    global risk
    global commission
    
    quantity = (0.02 * remaining_cash) // (current_price - (current_symbol.support * 0.97))
              
    if quantity > 1:
        current_symbol.bought = current_price
        current_symbol.stop_order = current_symbol.support * 0.97
        remaining_cash = remaining_cash - commission - (quantity * current_price)
        position[current_symbol.symbol] = quantity
        print("Buying ", quantity, "stocks of ", current_symbol.symbol, "At price", current_symbol.bought, "on date", date)
        risk += 1 
    else:
        pass

# %%
automatic_trader(symbol_list)
# Out:
# Buying  15.0 stocks of  TM At price 90.0 on date 2000-02-04
# Buying  1177.0 stocks of  AGX At price 0.69 on date 2000-03-03
# Buying  69.0 stocks of  AZZ At price 11.94 on date 2000-03-10
# Buying  52.0 stocks of  MSF At price 18.06 on date 2000-03-10
# Buying  8.0 stocks of  TG At price 32.38 on date 2000-03-10
# Buying  18.0 stocks of  CRUS At price 24.0 on date 2000-03-10
# Buying  16.0 stocks of  MCY At price 26.75 on date 2000-03-24
# Selling  52.0 stocks of MSF  at price 15.0 on date 2000-04-20
# Selling  18.0 stocks of CRUS  at price 17.13 on date 2000-04-20
# Buying  16.0 stocks of  OPOF At price 22.0 on date 2000-04-28
# Buying  31.0 stocks of  JOE At price 29.5 on date 2000-04-28
# Buying  18.0 stocks of  NFG At price 48.06 on date 2000-04-28
# Buying  8.0 stocks of  SWK At price 30.38 on date 2000-05-05
# Buying  30.0 stocks of  ANDE At price 9.0 on date 2000-06-02
# Selling  1177.0 stocks of AGX  at price 0.53 on date 2000-06-02
# Buying  242.0 stocks of  AGX At price 0.81 on date 2000-07-14
# Buying  3.0 stocks of  CRUS At price 35.19 on date 2000-09-08
# Buying  151.0 stocks of  ENSV At price 0.875 on date 2000-10-13
# Selling  3.0 stocks of CRUS  at price 23.5 on date 2000-12-08
# Buying  17.0 stocks of  MBWM At price 13.13 on date 2000-12-15
# Buying  4.0 stocks of  ANAT At price 73.5 on date 2000-12-29
# Buying  36.0 stocks of  BXMT At price 4.813 on date 2001-01-05
# Buying  4.0 stocks of  SPGI At price 65.0 on date 2001-04-20
# Selling  31.0 stocks of JOE  at price 26.26 on date 2001-05-18
# Selling  4.0 stocks of SPGI  at price 51.75 on date 2001-10-12
# Buying  43.0 stocks of  MHE At price 14.65 on date 2002-06-14
# Buying  8.0 stocks of  TLT At price 90.94 on date 2002-09-27
# Buying  6.0 stocks of  ENLK At price 28.9 on date 2003-05-02
# Selling  69.0 stocks of AZZ  at price 11.42 on date 2003-06-20
# Selling  8.0 stocks of TLT  at price 87.6 on date 2003-07-25
# Buying  11.0 stocks of  EZPW At price 6.81 on date 2003-09-26
# Buying  19.0 stocks of  LTM At price 15.9 on date 2003-10-24
# Buying  51.0 stocks of  EHI At price 15.05 on date 2003-11-07
# Buying  8.0 stocks of  TPL At price 58.24 on date 2003-11-14
# Buying  11.0 stocks of  ISRL At price 8.25 on date 2004-01-16
# Buying  5.0 stocks of  SLP At price 7.55 on date 2004-02-13
# Selling  8.0 stocks of TG  at price 14.91 on date 2004-02-13
# Buying  9.0 stocks of  JOE At price 41.99 on date 2004-03-05
# Selling  6.0 stocks of ENLK  at price 29.75 on date 2004-04-08
# Selling  9.0 stocks of JOE  at price 37.08 on date 2004-05-14
# Buying  8.0 stocks of  FE At price 40.35 on date 2004-08-06
# Buying  7.0 stocks of  GBR At price 4.35 on date 2005-01-28
# Selling  15.0 stocks of TM  at price 73.67 on date 2005-05-27
# Buying  2.0 stocks of  OZRK At price 34.56 on date 2006-04-21
# Buying  15.0 stocks of  DFE At price 55.7 on date 2006-08-25
# Buying  18.0 stocks of  GURE At price 2.0 on date 2006-10-27
# Selling  51.0 stocks of EHI  at price 13.97 on date 2007-01-05
# Buying  5.0 stocks of  IOO At price 77.13 on date 2007-04-13
# Buying  20.0 stocks of  GORO At price 3.3 on date 2007-04-20
# Buying  6.0 stocks of  NPO At price 41.19 on date 2007-05-18
# Selling  8.0 stocks of SWK  at price 56.78 on date 2007-08-03
# Selling  16.0 stocks of OPOF  at price 19.7501 on date 2007-10-12
# Selling  19.0 stocks of LTM  at price 14.25 on date 2007-11-23
# Buying  2.0 stocks of  PAC At price 48.87 on date 2007-12-07
# Selling  8.0 stocks of TPL  at price 41.51 on date 2008-02-01
# Buying  2.0 stocks of  SZK At price 84.84 on date 2008-02-22
# Buying  150.0 stocks of  SGOC At price 7.12 on date 2008-06-06
# Buying  4.0 stocks of  DRR At price 45.0 on date 2008-08-08
# Selling  150.0 stocks of SGOC  at price 6.7 on date 2008-10-10
# Selling  17.0 stocks of MBWM  at price 8.67 on date 2008-10-24
# Buying  2.0 stocks of  AZZ At price 28.97 on date 2009-01-09
# Buying  4.0 stocks of  BPOPM At price 21.0 on date 2009-02-20
# Buying  32.0 stocks of  SGOC At price 7.54 on date 2009-06-05
# Buying  31.0 stocks of  LINU At price 5.59 on date 2009-09-25
# Selling  4.0 stocks of DRR  at price 38.99 on date 2009-11-20
# Selling  36.0 stocks of BXMT  at price 1.751 on date 2010-08-20
# Selling  151.0 stocks of ENSV  at price 0.56 on date 2010-10-08
# Selling  15.0 stocks of DFE  at price 40.34 on date 2010-10-08
# Buying  32.0 stocks of  EFC At price 22.7 on date 2011-01-21
# Buying  4.0 stocks of  SWK At price 73.8 on date 2011-02-04
# Buying  55.0 stocks of  ONCS At price 1.8 on date 2011-05-20
# Selling  32.0 stocks of EFC  at price 17.3 on date 2011-12-09
# Buying  90.0 stocks of  RMGN At price 9.71 on date 2012-01-20
# Selling  32.0 stocks of SGOC  at price 0.868 on date 2012-01-27
# Buying  27.0 stocks of  SZC At price 25.07 on date 2012-10-19
# Selling  27.0 stocks of SZC  at price 22.87 on date 2012-11-23
# Buying  2.0 stocks of  V At price 149.93 on date 2012-11-30
# Buying  16.0 stocks of  WHF At price 15.04 on date 2013-02-08
# Buying  7.0 stocks of  CTR At price 23.27 on date 2013-04-12
# Buying  2.0 stocks of  HD At price 73.66 on date 2013-04-12
# Buying  2.0 stocks of  FI At price 32.43 on date 2013-10-04
# Buying  2.0 stocks of  PEX At price 44.61 on date 2013-10-18
# Selling  2.0 stocks of FI  at price 25.13 on date 2013-11-22
# Selling  43.0 stocks of MHE  at price 11.7 on date 2013-12-06
# Buying  11.0 stocks of  FNCL At price 26.15 on date 2013-12-27
# Buying  8.0 stocks of  CPTA At price 20.25 on date 2014-01-17
# Buying  3.0 stocks of  GQRE At price 51.52 on date 2014-04-11
# Selling  31.0 stocks of LINU  at price 3.17 on date 2014-06-20
# Selling  2.0 stocks of SZK  at price 31.832 on date 2014-06-20
# Buying  2.0 stocks of  KTWO At price 17.978 on date 2014-08-01
# Selling  8.0 stocks of FE  at price 35.15 on date 2014-10-10
# Buying  2.0 stocks of  VAC At price 60.23 on date 2014-10-10
# Buying  3.0 stocks of  CEMI At price 4.09 on date 2014-10-10
# Buying  12.0 stocks of  MELR At price 15.5 on date 2015-12-18
# Buying  5.0 stocks of  PTMC At price 24.16 on date 2016-04-22
# Selling  8.0 stocks of CPTA  at price 13.62 on date 2016-05-13
# Selling  16.0 stocks of WHF  at price 11.16 on date 2016-06-24
# Selling  2.0 stocks of PEX  at price 38.4261 on date 2016-06-24
# Selling  90.0 stocks of RMGN  at price 1.03 on date 2016-06-24
# Buying  9.0 stocks of  MCX At price 25.59 on date 2016-08-05
# Selling  7.0 stocks of CTR  at price 12.71 on date 2016-12-02
# Selling  2.0 stocks of V  at price 78.848 on date 2016-12-30
# Buying  2.0 stocks of  TUSK At price 19.87 on date 2017-01-20
# Buying  11.0 stocks of  BERN At price 26.0 on date 2017-12-01
# Buying  3.0 stocks of  SPSM At price 30.645 on date 2017-12-08
# Buying  4.0 stocks of  CEFS At price 21.71 on date 2018-01-12
# Selling  242.0 stocks of AGX  at price 40.075 on date 2018-06-08
# Buying  2.0 stocks of  FICO At price 201.325 on date 2018-06-15
# Buying  7.0 stocks of  SPGI At price 202.75 on date 2018-06-15
# Buying  22.0 stocks of  WBIL At price 27.21 on date 2018-06-15
# Buying  8.0 stocks of  EA At price 151.2581 on date 2018-07-13
# Win Percentage
# 36.36363636363637
# Profit 5635.4328000000005

# %%
print("Remaining Cash ::" , remaining_cash)
# Out:
# Remaining Cash :: 6311.277000000003

# %%
current_profit = 0
for key in position:
    current_profit = position[key] * (stock_equities[key].current_price - stock_equities[key].bought)
    remaining_cash += position[key] * stock_equities[key].current_price
    profit += current_profit
    
    if current_profit > 0:
        win += 1
    else:
        loss += 1
    
    if profit > max_profit:
        max_profit = profit
    
    if profit < min_loss:
        min_loss = profit
    
    
print("Maximum Profit is ", max_profit)
print("Minimum Loss is ", min_loss)
print("Profit", profit)
print("Remaining cash ", remaining_cash)
print("Win Percentage")            
print((win/(loss + win))*100)
# Out:
# Maximum Profit is  9762.266200000004
# Minimum Loss is  -786.2
# Profit 9755.056200000003
# Remaining cash  19390.056200000006
# Win Percentage
# 53.333333333333336
