# %%
import pandas as pd
import time
from datetime import datetime
from alpha_vantage.timeseries import TimeSeries
import random
import urllib
import sqlalchemy
import matplotlib.pyplot as plt
import sys
import tensorflow as tf
import keras
import numpy as np

position = {}
remaining_cash = 10000.00
capital = 10000.00
loss = 0
win = 0
total_valuation = 0    
profit = 0
commission = 5
max_profit = 0
min_loss = 0

# %%
params = urllib.parse.quote("DRIVER={ODBC Driver 13 for SQL Server};SERVER=localhost;DATABASE=StocksDMW;Trusted_Connection=yes")
engine = sqlalchemy.create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)

# %%
symbols = """
select distinct(name) from stockdatadaily order by name
"""
symbol_list = pd.read_sql(symbols, engine)

# %%
symbol_list = symbol_list['name'].tolist()

# %% [markdown]
# <h1> Instantation of variables

# %%
class equity():
    bought = None
    support = None
    resistance = None
    resistance_date = None
    stop_order = 0.0
    times_bought = 0
    symbol = None
    dataframe = None
    current_price = None
    training = None
    flag_for_wins = False
    
    def __init__(self, name):
        self.symbol = name
        self.training = list()

sql1= """
select distinct(name) from stockdatadaily order by name
"""
names = pd.read_sql(sql1,engine)['name'].tolist()

stock_equities = {}
for name in names:
    stock_equities[name] = equity(name)

# %% [markdown]
# <h1> Updating resources

# %%
cursor = len(symbol_list)
percent = cursor // 100


counter = 0
percentage = 0
for symbol in symbol_list:
    if(counter % percent == 0 ):
        print(percentage , "% done")
        percentage += 1
    symbol_data = """
    select * from stockdatadaily where name = '%s'
    """ % symbol
    counter += 1
    stock_equities[symbol].dataframe = pd.read_sql(symbol_data,engine)
# Out:
# 0 % done
# 1 % done
# 2 % done
# 3 % done
# 4 % done
# 5 % done
# 6 % done
# 7 % done
# 8 % done
# 9 % done
# 10 % done
# 11 % done
# 12 % done
# 13 % done
# 14 % done
# 15 % done
# 16 % done
# 17 % done
# 18 % done
# 19 % done
# 20 % done
# 21 % done
# 22 % done
# 23 % done
# 24 % done
# 25 % done
# 26 % done
# 27 % done
# 28 % done
# 29 % done
# 30 % done
# 31 % done
# 32 % done
# 33 % done
# 34 % done
# 35 % done
# 36 % done
# 37 % done
# 38 % done
# 39 % done
# 40 % done
# 41 % done
# 42 % done
# 43 % done
# 44 % done
# 45 % done
# 46 % done
# 47 % done
# 48 % done
# 49 % done
# 50 % done
# 51 % done
# 52 % done
# 53 % done
# 54 % done
# 55 % done
# 56 % done
# 57 % done
# 58 % done
# 59 % done
# 60 % done
# 61 % done
# 62 % done
# 63 % done
# 64 % done
# 65 % done
# 66 % done
# 67 % done
# 68 % done
# 69 % done
# 70 % done
# 71 % done
# 72 % done
# 73 % done
# 74 % done
# 75 % done
# 76 % done
# 77 % done
# 78 % done
# 79 % done
# 80 % done
# 81 % done
# 82 % done
# 83 % done
# 84 % done
# 85 % done
# 86 % done
# 87 % done
# 88 % done
# 89 % done
# 90 % done
# 91 % done
# 92 % done
# 93 % done
# 94 % done
# 95 % done
# 96 % done
# 97 % done
# 98 % done
# 99 % done

# %%
sql_dates = """
select distinct(date) from stockdatadaily order by date
"""
dates = pd.read_sql(sql_dates, engine)['date'].tolist()

# %%
from keras import backend as K

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# <h1> Loading ANN model </h1>

# %%
model = tf.keras.models.load_model('61-58DailyANN.model', custom_objects={'sensitivity': sensitivity})

# %% [markdown]
# <h1> Trading strategy with the training sets generation

# %%
def automatic_trader(symbol_list):
    global position
    global remaining_cash
    global loss
    global profit
    global win
    global total_valuation
    global list_for_Risk
    global capital
    global max_profit
    global min_loss
    
    for date in dates:
        symbols_in_date = """
        select distinct(name) from stockdatadaily where date = '%s'
        """ % date
        symbols = pd.read_sql(symbols_in_date,engine)['name'].tolist()
        for symbol in symbol_list:
            if symbol in symbols:
                current_symbol = stock_equities[symbol]
                data_till_date = data_extract(current_symbol.dataframe,date)
                current_price = data_till_date.tail(1)['2. high'].values[0]
                current_symbol.current_price = current_price
                if len(data_till_date) == 1:
                    continue
                if current_symbol.bought == None:
                    if resist_condition(data_till_date):
                        current_symbol.resistance, current_symbol.resistance_date = resistance_cal(data_till_date)
                        
                    if current_symbol.resistance != None and support_condition(data_till_date, current_symbol.resistance):
                        current_symbol.support = support_cal(current_symbol.resistance_date, data_till_date)
                    
                    if current_symbol.support != None and current_symbol.resistance !=None and buy_condition(current_symbol.resistance, data_till_date):
                        training_inst = training_set_extractor(data_till_date, date)
                        for_predict = np.asarray(tf.keras.utils.normalize([[training_inst[0], training_inst[1]]]))
                        if(model.predict(for_predict) > 0.5):
                            buy_stocks(current_price, current_symbol, date)
        
                            
                else:
                    if current_symbol.flag_for_wins == False and current_symbol.stop_order > current_symbol.bought:
                                
                                win += 1
                                current_symbol.flag_for_wins = True
                                
                        
                        
                    if current_symbol.stop_order > current_price:
                                             
                        current_symbol.stop_order = None
                        print("Selling ",position[symbol], "stocks of", symbol, " at price", current_price, "on date", date)
                        sold = current_price * position[symbol] - commission
                        profit_today = sold - current_symbol.bought * position[symbol]
                        if profit_today > 0:
                            
                            if current_symbol.flag_for_wins == False:
                                win += 1
                                
                            current_symbol.flag_for_wins = False
                            
                        else:
                            loss += 1
                            
                            current_symbol.flag_for_wins = False
                    
                            
                        profit += profit_today
                        
                        if profit > max_profit:
                            max_profit = profit
                        if profit < min_loss:
                            min_loss = profit
                        
                        remaining_cash = remaining_cash + sold
                        del position[symbol]
                        current_symbol.bought = None
                        
                        
                    else:
                        if resist_condition(data_till_date):
                            current_symbol.resistance, current_symbol.resistance_date = resistance_cal( data_till_date)
                        
                        if current_symbol.resistance and support_condition(data_till_date,current_symbol.resistance):
                            current_symbol.support = support_cal(current_symbol.resistance_date, data_till_date)
                        
                        if current_symbol.resistance != None and current_symbol.support != None and buy_condition(current_symbol.resistance, data_till_date):
                            current_symbol.stop_order = current_symbol.support * 0.97
                    
                        
    print("Win Percentage")            
    print((win/(loss + win))*100)
    print("Profit",profit)
    print("\n")

# %% [markdown]
# <h1> Helper functions for the strategy

# %%
def resistance_cal(data_resistance):

    highest_data = data_resistance[data_resistance['2. high'] == max(data_resistance['2. high'])]
    date = highest_data['date'].values[0]
    resistance = highest_data['2. high'].values[0]


    return round(resistance + 0.005,2), date                

def support_cal(resist_date, data_support):

    # data since the last resistance date until today's date.
    data_since_last_resistance = data_support.loc[data_support['date'] >= resist_date]
    # data variable here contains the row of the dataframe with the lowest value of '3. low' values
    data = data_since_last_resistance.loc[data_since_last_resistance['3. low']==min(data_since_last_resistance['3. low'])]
    # support here contains the lowest value of stock since last resistance date
    support = data['3. low'].values[0]


    # we return the support value and the date of the support value
    return support



def resist_condition(  data_resistance):

    recent_data = data_resistance.tail(2)   # Getting yesterday's and today's price
    yesterday_price = recent_data['3. low'].values[0]   # Yesterday's prices
    today_price = recent_data['3. low'].values[1]       # today's prices  


    if(today_price < yesterday_price):
        return True
    else:
        return False
    # If today's lowest price of the stock is less than yesterday's lowest price of the stock,
    # then Resistance condition is met

def support_condition(   data_support, resist_passed):
    current_price = data_support.tail(1)['2. high'].values[0] # Today's price of the stock
    if(current_price > resist_passed):
        return True
    else:
        return False
    #If the current price of the stock is greater than the current resistance value that is passed then,
    # the support condition is met     

def buy_condition(resist, data):
    if resist < data.tail(1)['2. high'].values[0]:
        return True
    else:
        return False       

def buy_stocks(current_price, current_symbol, date):
    global position
    global remaining_cash
    global commission
    
    quantity = (0.02 * remaining_cash) // (current_price - (current_symbol.support * 0.97))
              
    if quantity > 1:
        current_symbol.bought = current_price
        current_symbol.stop_order = current_symbol.support * 0.97
        remaining_cash = remaining_cash - commission - (quantity * current_price)
        position[current_symbol.symbol] = quantity
        print("Buying ", quantity, "stocks of ", current_symbol.symbol, "At price", current_symbol.bought, "on date", date)

    else:
        pass

def data_extract(data, *args):
    if len(args) == 2:
        data = data.loc[data['date'] >= args[0]]
        data = data.loc[data['date'] <= args[1]]
    else:
        data = data.loc[data['date'] <= args[0]]
    return data

def training_set_extractor(data, date):
    lastFrom = pd.to_datetime(date)

    destDate = lastFrom - pd.Timedelta(days=30)
    lastFrom = str(lastFrom.date())
    destDate = str(destDate.date())

    df = pd.DataFrame()
    df = data[(data['date'] >= destDate) & (data['date'] <= lastFrom)]

    df = df.set_index('date')

    df.index = pd.DatetimeIndex(df.index)
    idx = pd.date_range(destDate, lastFrom)
    df = df.reindex(idx, fill_value=0)
    
    highs = df['2. high'].tolist()
    volumes = df['5. volume'].tolist()
    lows = df['3. low'].tolist()
    
    for i in range(1, len(highs)):
        if highs[i] == 0:
            highs[i] = highs[i-1]
        if volumes[i] == 0:
            volumes[i] = volumes[i-1]
        if lows[i] == 0:
            lows[i] = lows[i-1]
        
    
    training_instance = [highs, volumes, lows, 'na']
    
    return training_instance[:]

# %%
automatic_trader(symbol_list)
# Out:
# Buying  29.0 stocks of  RCI At price 28.75 on date 2000-01-14
# Buying  258.0 stocks of  LCII At price 9.44 on date 2000-01-19
# Buying  277.0 stocks of  OIA At price 8.063 on date 2000-01-28
# Buying  10.0 stocks of  TDW At price 35.94 on date 2000-01-31
# Buying  40.0 stocks of  CBL At price 21.81 on date 2000-02-02
# Buying  6.0 stocks of  AVA At price 24.88 on date 2000-02-03
# Buying  96.0 stocks of  CXH At price 8.94 on date 2000-02-03
# Buying  10.0 stocks of  YPF At price 37.38 on date 2000-02-08
# Buying  17.0 stocks of  EEA At price 16.5 on date 2000-02-09
# Selling  258.0 stocks of LCII  at price 8.19 on date 2000-02-28
# Buying  61.0 stocks of  UTMD At price 7.62 on date 2000-03-02
# Buying  3.0 stocks of  SIRI At price 54.0 on date 2000-03-21
# Buying  27.0 stocks of  HXL At price 6.81 on date 2000-04-19
# Selling  61.0 stocks of UTMD  at price 7.0 on date 2000-05-23
# Buying  19.0 stocks of  CAMT At price 7.75 on date 2000-08-07
# Selling  10.0 stocks of YPF  at price 34.0 on date 2000-09-01
# Buying  9.0 stocks of  ISSC At price 18.75 on date 2000-10-20
# Buying  4.0 stocks of  DEO At price 39.99 on date 2001-03-28
# Selling  29.0 stocks of RCI  at price 13.9 on date 2001-04-11
# Buying  4.0 stocks of  BWA At price 45.45 on date 2001-04-26
# Selling  3.0 stocks of SIRI  at price 10.7 on date 2001-06-28
# Buying  12.0 stocks of  UTMD At price 11.35 on date 2001-06-29
# Selling  10.0 stocks of TDW  at price 35.7 on date 2001-08-16
# Selling  17.0 stocks of EEA  at price 8.07 on date 2001-08-30
# Selling  9.0 stocks of ISSC  at price 7.05 on date 2001-10-08
# Buying  18.0 stocks of  AMN At price 24.65 on date 2001-11-21
# Selling  19.0 stocks of CAMT  at price 3.9 on date 2001-12-12
# Buying  21.0 stocks of  MPX At price 5.44 on date 2002-01-07
# Selling  27.0 stocks of HXL  at price 3.09 on date 2002-02-26
# Buying  15.0 stocks of  LCII At price 15.35 on date 2002-04-29
# Buying  12.0 stocks of  NNN At price 15.75 on date 2002-10-24
# Selling  6.0 stocks of AVA  at price 9.87 on date 2002-11-12
# Selling  18.0 stocks of AMN  at price 9.56 on date 2003-05-12
# Buying  24.0 stocks of  KRO At price 18.38 on date 2003-12-18
# Buying  34.0 stocks of  AVHI At price 36.109 on date 2003-12-26
# Buying  4.0 stocks of  YPF At price 43.9 on date 2004-01-20
# Buying  12.0 stocks of  IRL At price 21.9 on date 2005-03-17
# Buying  6.0 stocks of  ATI At price 36.66 on date 2005-12-29
# Selling  40.0 stocks of CBL  at price 42.04 on date 2006-01-13
# Buying  11.0 stocks of  HXL At price 23.3 on date 2006-04-07
# Buying  6.0 stocks of  RCI At price 42.75 on date 2006-06-12
# Buying  17.0 stocks of  DLN At price 52.33 on date 2006-07-26
# Buying  11.0 stocks of  PZD At price 25.88 on date 2006-12-04
# Buying  3.0 stocks of  DBE At price 26.01 on date 2007-03-05
# Selling  6.0 stocks of RCI  at price 35.5 on date 2007-04-13
# Buying  2.0 stocks of  MVV At price 94.57 on date 2007-05-07
# Buying  12.0 stocks of  FEX At price 30.08 on date 2007-06-05
# Selling  2.0 stocks of MVV  at price 83.76 on date 2007-08-28
# Selling  277.0 stocks of OIA  at price 7.81 on date 2007-10-31
# Selling  34.0 stocks of AVHI  at price 46.59 on date 2007-11-01
# Buying  2.0 stocks of  TDW At price 71.92 on date 2007-11-02
# Buying  19.0 stocks of  RSX At price 51.37 on date 2007-11-06
# Selling  17.0 stocks of DLN  at price 52.94 on date 2008-01-22
# Selling  12.0 stocks of FEX  at price 26.68 on date 2008-02-14
# Selling  24.0 stocks of KRO  at price 23.37 on date 2008-03-25
# Selling  6.0 stocks of ATI  at price 84.22 on date 2008-04-08
# Selling  12.0 stocks of IRL  at price 20.32 on date 2008-05-30
# Selling  19.0 stocks of RSX  at price 28.46 on date 2008-10-01
# Selling  96.0 stocks of CXH  at price 7.57 on date 2008-11-05
# Selling  11.0 stocks of PZD  at price 17.16 on date 2008-12-10
# Selling  4.0 stocks of DEO  at price 57.98 on date 2009-01-06
# Selling  3.0 stocks of DBE  at price 23.0 on date 2009-01-06
# Selling  4.0 stocks of BWA  at price 22.86 on date 2009-01-12
# Selling  11.0 stocks of HXL  at price 6.78 on date 2009-02-25
# Selling  15.0 stocks of LCII  at price 6.88 on date 2009-02-25
# Selling  12.0 stocks of NNN  at price 15.02 on date 2009-03-12
# Selling  4.0 stocks of YPF  at price 29.0 on date 2009-04-29
# Buying  3.0 stocks of  IOC At price 48.25 on date 2009-10-30
# Buying  38.0 stocks of  QABA At price 23.952 on date 2010-03-03
# Buying  164.0 stocks of  JMT At price 25.075 on date 2010-03-15
# Buying  2.0 stocks of  MLNX At price 25.47 on date 2010-04-20
# Selling  164.0 stocks of JMT  at price 23.55 on date 2010-05-28
# Buying  7.0 stocks of  NNN At price 27.19 on date 2010-10-29
# Buying  29.0 stocks of  BUR At price 10.19 on date 2010-12-20
# Buying  29.0 stocks of  KRO At price 54.94 on date 2011-03-09
# Buying  66.0 stocks of  XPO At price 3.24 on date 2011-08-05
# Selling  29.0 stocks of KRO  at price 20.92 on date 2011-08-23
# Buying  2.0 stocks of  SGG At price 105.56 on date 2011-08-23
# Buying  23.0 stocks of  USMV At price 28.83 on date 2012-06-18
# Selling  29.0 stocks of BUR  at price 5.07 on date 2012-08-14
# Buying  10.0 stocks of  JMT At price 27.18 on date 2012-09-24
# Buying  42.0 stocks of  SXE At price 23.9 on date 2012-11-12
# Selling  2.0 stocks of MLNX  at price 53.35 on date 2013-01-04
# Buying  13.0 stocks of  BWG At price 20.9 on date 2013-02-15
# Buying  2.0 stocks of  FEX At price 33.07 on date 2013-03-01
# Buying  7.0 stocks of  HXL At price 28.38 on date 2013-03-11
# Buying  8.0 stocks of  AMU At price 28.05 on date 2013-04-05
# Selling  2.0 stocks of SGG  at price 59.382 on date 2013-06-28
# Selling  10.0 stocks of JMT  at price 24.5 on date 2013-07-05
# Buying  10.0 stocks of  ICOL At price 27.35 on date 2013-08-06
# Selling  42.0 stocks of SXE  at price 22.61 on date 2013-08-07
# Selling  13.0 stocks of BWG  at price 16.17 on date 2013-08-30
# Selling  66.0 stocks of XPO  at price 20.51 on date 2013-11-12
# Buying  2.0 stocks of  DLN At price 65.48 on date 2013-12-10
# Buying  5.0 stocks of  HTH At price 23.04 on date 2013-12-17
# Selling  10.0 stocks of ICOL  at price 23.15 on date 2014-01-28
# Buying  2.0 stocks of  AER At price 38.585 on date 2014-02-05
# Buying  33.0 stocks of  FNCL At price 26.55 on date 2014-03-18
# Buying  59.0 stocks of  RDIV At price 28.16 on date 2014-05-08
# Buying  14.0 stocks of  CHMI At price 19.42 on date 2014-06-05
# Buying  2.0 stocks of  XPO At price 34.88 on date 2014-09-10
# Selling  14.0 stocks of CHMI  at price 18.62 on date 2014-12-29
# Buying  16.0 stocks of  DIAX At price 17.35 on date 2014-12-29
# Buying  4.0 stocks of  CLNS At price 22.75 on date 2014-12-29
# Buying  7.0 stocks of  NEWT At price 16.1 on date 2015-02-19
# Selling  2.0 stocks of TDW  at price 28.35 on date 2015-03-02
# Buying  7.0 stocks of  SPYB At price 54.0 on date 2015-03-05
# Selling  8.0 stocks of AMU  at price 27.64 on date 2015-03-09
# Buying  18.0 stocks of  TACO At price 10.5 on date 2015-03-12
# Selling  7.0 stocks of NNN  at price 39.93 on date 2015-04-29
# Buying  19.0 stocks of  EQAL At price 26.4 on date 2015-05-21
# Selling  2.0 stocks of DLN  at price 69.4 on date 2015-09-16
# Selling  16.0 stocks of DIAX  at price 13.62 on date 2015-09-22
# Selling  4.0 stocks of CLNS  at price 14.25 on date 2015-09-29
# Selling  19.0 stocks of EQAL  at price 24.4137 on date 2015-10-12
# Selling  7.0 stocks of SPYB  at price 48.869 on date 2015-11-11
# Selling  38.0 stocks of QABA  at price 33.89 on date 2016-02-08
# Selling  33.0 stocks of FNCL  at price 24.496 on date 2016-02-09
# Buying  21.0 stocks of  SCWX At price 16.23 on date 2016-06-15
# Buying  17.0 stocks of  EMSH At price 78.53 on date 2016-07-07
# Buying  2.0 stocks of  AMN At price 43.65 on date 2016-08-03
# Buying  5.0 stocks of  NNN At price 51.16 on date 2016-08-18
# Buying  2.0 stocks of  LCII At price 96.12 on date 2016-09-13
# Buying  6.0 stocks of  CAKE At price 64.36 on date 2016-12-07
# Buying  4.0 stocks of  RFAP At price 53.899 on date 2016-12-08
# Buying  8.0 stocks of  EQAL At price 27.24 on date 2016-12-16
# Selling  21.0 stocks of SCWX  at price 11.05 on date 2016-12-23
# Buying  13.0 stocks of  WVVIP At price 5.9 on date 2017-01-17
# Buying  6.0 stocks of  VSM At price 29.67 on date 2017-02-06
# Buying  6.0 stocks of  LVHD At price 29.4 on date 2017-02-14
# Buying  4.0 stocks of  DLN At price 83.16 on date 2017-02-22
# Buying  3.0 stocks of  FNCL At price 35.7629 on date 2017-04-26
# Selling  5.0 stocks of NNN  at price 41.55 on date 2017-05-04
# Selling  2.0 stocks of LCII  at price 95.25 on date 2017-06-08
# Buying  2.0 stocks of  IAC At price 104.5 on date 2017-06-09
# Selling  6.0 stocks of CAKE  at price 50.57 on date 2017-06-22
# Buying  2.0 stocks of  SVRA At price 6.5 on date 2017-06-22
# Buying  6.0 stocks of  BST At price 23.8 on date 2017-07-17
# Buying  5.0 stocks of  DFNL At price 22.19 on date 2017-07-21
# Buying  6.0 stocks of  GSEW At price 41.7199 on date 2017-10-09
# Buying  7.0 stocks of  RNLC At price 21.2082 on date 2017-11-28
# Buying  2.0 stocks of  DINT At price 20.56 on date 2018-03-12
# Selling  17.0 stocks of EMSH  at price 73.964 on date 2018-07-02
# Selling  2.0 stocks of AMN  at price 60.95 on date 2018-07-03
# Selling  2.0 stocks of DINT  at price 19.13 on date 2018-07-03
# Buying  7.0 stocks of  EAST At price 8.44 on date 2018-07-03
# Win Percentage
# 42.168674698795186
# Profit -2337.8296999999993

# %%
current_profit = 0
for key in position:
    current_profit = position[key] * (stock_equities[key].current_price - stock_equities[key].bought)
    remaining_cash += position[key] * stock_equities[key].current_price
    profit += current_profit
    
    if current_profit > 0:
        win += 1
    else:
        loss += 1
    
    if profit > max_profit:
        max_profit = profit
    
    if profit < min_loss:
        min_loss = profit
    
    
print("Maximum Profit is ", max_profit)
print("Minimum Loss is ", min_loss)
print("Profit", profit)
print("Remaining cash ", remaining_cash)
print("Win Percentage")            
print((win/(loss + win))*100)
# Out:
# Maximum Profit is  1390.4287000000013
# Minimum Loss is  -3186.3829999999994
# Profit 1390.4287000000013
# Remaining cash  10960.428699999995

# %%
remaining_cash
